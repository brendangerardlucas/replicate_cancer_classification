# %% [markdown]
# # Replicating (at least part of) "Classification of Cancer Types Using Graph Convolutional Neural Networks" (2020) (doi: 10.3389/fphy.2020.00203)

# %% [markdown]
# # Prefix: rpy2 allows us to use R in code cells in the following way

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# x <- c(1, 2, 3, 4, 5)
# mean(x)
# Out:
# [1] 3

# %% [markdown]
# # Installing R Packages

# %%
# %%R
# options(timeout = 600)
#
# install.packages("BiocManager")
#
# install.packages("stringi", repos="https://cloud.r-project.org")
# install.packages("data.table", repos="https://cloud.r-project.org")
#
# BiocManager::install("TCGAbiolinksGUI.data", update = FALSE, ask = FALSE)
# BiocManager::install("TCGAbiolinks")
# Out:
# * installing *source* package ‘BiocManager’ ...
# ** this is package ‘BiocManager’ version ‘1.30.27’
# ** package ‘BiocManager’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (BiocManager)
# * installing *source* package ‘stringi’ ...
# ** this is package ‘stringi’ version ‘1.8.7’
# ** package ‘stringi’ successfully unpacked and MD5 sums checked
# ** using staged installation
# checking for R_HOME... /usr/lib/R
# checking for R... /usr/lib/R/bin/R
# checking for endianness... little
# checking for cat... /usr/bin/cat
# ...

# %% [markdown]
# # Testing R Packages

# %%
# %%R
# .libPaths()
#
# "TCGAbiolinks" %in% installed.packages()
# Out:
# [1] TRUE

# %% [markdown]
# # Downloading the data with R
#
# Citations 15 (Mostavi M, Chiu Y.-C, Huang Y, Chen Y. Convolutional neural network models for cancer type prediction based on gene expression. BMC Med Genomics. (2020) 13:1–13. doi: 10.1186/s12920-020-0677-2) and 25 (Colaprico A, Silva TC, Olsen C, Garofano L, Cava C, Garolini D, et al. TCGAbiolinks: an R/Bioconductor package for integrative analysis of TCGA data. Nucleic Acids Res. (2015) 44:e71. doi: 10.1093/nar/gkv1507)
#
# The above citations describe the data loading in R, according to the paper.

# %%
# %%R
# library(TCGAbiolinks)
# library(SummarizedExperiment)
# library(dplyr)
#
# projects <- getGDCprojects()
#
# tcga_projects <- projects$project_id[grep("TCGA-", projects$project_id)]
# print(length(tcga_projects))
# print(head(tcga_projects))
# Out:
# [1] 33
# [1] "TCGA-LGG"  "TCGA-BRCA" "TCGA-LAML" "TCGA-UCS"  "TCGA-GBM"  "TCGA-THYM"
# ...
#  ______  ___  ____   ___
#    ||   |    |      |   | |    o  __  |   o  _         __
#    ||   |    | ___  |___| |__  | |  | |   | | | | |_/ |__
#    ||   |___ |____| |   | |__| | |__| |__ | | |_| | \  __|
#  ------------------------------------------------------------
#  Query, download & analyze - GDC
#  Version:2.38.0
# ...
#
# Loading required package: MatrixGenerics
# Loading required package: matrixStats
#
# Attaching package: ‘MatrixGenerics’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
# ...

# %%
# %%R
#
# for (proj in tcga_projects) {
#     message(paste("-----------------------------------"))
#     message(paste("Starting download for: ", proj))
#
#     tryCatch({
#
#         summary <- getProjectSummary(proj)
#         target_cat_row <- grep("Transcriptome", summary$data_categories$data_category)
#         target_category <- summary$data_categories$data_category[target_cat_row]
#
#         query <- GDCquery(
#             project = proj,
#             data.category = target_category,
#             data.type = "Gene Expression Quantification",
#             workflow.type = "STAR - Counts"
#         )
#
#         GDCdownload(query, method = "api", files.per.chunk = 10)
#         message(paste("Successfully downloaded:", proj))
#
#     }, error = function(e) {
#         message(paste("ERROR downloading", proj, ":", e$message))
#     })
# }
# Out:
# Downloading: 10 MB
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Downloading: 5.8 MB
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Downloading: 5.5 MB
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ...

# %% [markdown]
# Note: it is probably better to replicate the PPI+Singleton graph model than the pure PPI graph model, as the PPI+Singleton one is not much more complicated and performed better.

# %% [markdown]
# # Preprocessing Data in Python (Requires 50gb of RAM)

# %%
import os
import glob
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import MinMaxScaler

def load_and_preprocess_tcga(root_dir="GDCdata"):
    print(f"Scanning {root_dir} for data files...")

    # 1. Find all RNA-Seq files

    file_pattern = os.path.join(root_dir, "TCGA-*", "**", "*.rna_seq.augmented_star_gene_counts.tsv")
    files = glob.glob(file_pattern, recursive = True)

    if len(files) == 0:
        raise ValueError(f"No files found in {root_dir}! Check your directory structure.")

    print(f"Found {len(files)} samples. Beginning processing...")

    sample_data_list = []
    sample_labels = []

    for i, file_path in enumerate(files):
        if i % 100 == 0:
            print(f"Processed {i}/{len(files)} files...")

        # Extract Project ID (Label) from path (e.g., "TCGA-BRCA")
        # Path structure: GDCdata/TCGA-BRCA/...
        parts = file_path.split(os.sep)
        project_id = next((s for s in parts if s.startswith("TCGA-")), "Unknown")

        try:
            # Read Data
            # sep='\t': It is a Tab separated file
            # comment='#': Ignores the # gene-model..." line
            # header=0:: (Default) Uses the first valid line ("gene_id", "gene_name"...) as columns
            df = pd.read_csv(file_path, sep='\t', comment='#')

            # Filter for valid Ensembl IDs (Removes N_unmapped, N_ambiguous, etc.)
            df = df[df['gene_id'].str.startswith('ENSG')]

            # Set Gene ID as index so we can align samples later
            df = df.set_index('gene_id')

            # Extract the FPKM column
            # We explicitly look for 'fpkm_unstranded' based on file
            if 'fpkm_unstranded' in df.columns:
                series = df['fpkm_unstranded']
            else:
                raise ValueError(f"Column 'fpkm_unstranded' not found in {file_path}")

            # Rename the series to the file name (or UUID) to avoid duplicates
            series.name = os.path.basename(file_path)

            sample_data_list.append(series)
            sample_labels.append(project_id)

        except Exception as e:
            print(f"Error reading {file_path}: {e}")

    print("Aggregating samples into matrix...")
    # Concatenate all series into a DataFrame
    # Columns = Samples, Rows = Genes
    expression_df = pd.concat(sample_data_list, axis=1)

    # Transpose: Rows = Samples, Columns = Genes
    X = expression_df.T.values
    genes = expression_df.index.values
    labels = np.array(sample_labels)

    print(f"Raw Data Shape: X.shape (Samples x Genes)")

    # -
    # Ramirez et al. preprocessing steps (page 2-3 of paper)
    # -

    # Step 1: Log2 Transformation
    print("Applying log2(x+1) transform...")
    X = np.log2(X + 1)

    # Step 2: Statistical Filtering
    print("Calculating gene statistics...")
    gene_means = np.mean(X, axis=0)
    gene_sds = np.std(X, axis=0)

    mask = (gene_means > 0.5) & (gene_sds > 0.8)

    X_filtered = X[:, mask]
    final_genes = genes[mask]

    print(f"Filtered Data Shape: {X_filtered.shape}")
    print(f"Genes retained :{len(final_genes)}")

    # Step 3: Standardization
    print("Applying Min-Max Scaling (0-1)...")
    scaler = MinMaxScaler(feature_range(0, 1))
    X_scaled = scaler.fit_transform(X_filtered)

    return X_scaled, labels, final_genes

# Run it
try:
    features_numpy, labels_numpy, gene_names = load_and_preprocess_tcga()

    features = torch.FloatTensor(features_numpy)

    # Convert string labels (TCGA-BRCA) to integers (, 1, 2, ...)
    unique_labels = np.unique(labels_numpy)
    label_map = {label: i for i, label in enumerate(unique_labels)}
    labels_int = np.array([label_map[l] for l in labels_numpy])
    labels = torch.LongTensor(labels_int)

    print("\n--- DATA READY ---")
    print("Features:", features.shape)
    print("Labels:", labels.shape)
    print(f"Detected {len(unique_labels)} Classes: {unique_labels}")

except Exception as e:
    print(f"Failed: {e}")
# Out:
# Scanning GDCdata for data files...
# Found 11505 samples. Beginning processing...
# Processed 0/11505 files...
# Processed 100/11505 files...
# Processed 200/11505 files...
# Processed 300/11505 files...
# Processed 400/11505 files...
# Processed 500/11505 files...
# Processed 600/11505 files...
# Processed 700/11505 files...
# Processed 800/11505 files...
# Processed 900/11505 files...
# Processed 1000/11505 files...
# Processed 1100/11505 files...
# Processed 1200/11505 files...
# Processed 1300/11505 files...
# Processed 1400/11505 files...
# Processed 1500/11505 files...
# Processed 1600/11505 files...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 104
#     102 # Run it
#     103 try:
# --> 104     features_numpy, labels_numpy, gene_names = load_and_preprocess_tcga()
#     106     features = torch.FloatTensor(features_numpy)
# ...

# %% [markdown]
# # Neural Network
